# %%
import pandas as pd
import numpy as np
import sklearn as sk
import tensorflow as tf
import time
import scipy
import os
import beautifulsoup
df = pd.read_csv('C:/Users/Roland/MLOps/Udacity/data/winequality-red.csv', sep=';')
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# 3      9.8        6
# 4      9.4        5

# %%
import time
import os
import flask
import pytest
# Flask initalization, routing, return, & requests

# %%
with open('books_published_last_two_years.txt') as f:
    recent_books = f.read().split('\n')
    
with open('all_coding_books.txt') as f:
    coding_books = f.read().split('\n')

# %%
start = time.time()
recent_coding_books = []

for book in recent_books:
    if book in coding_books:
        recent_coding_books.append(book)

print(len(recent_coding_books))
print('Duration: {} seconds'.format(time.time() - start))

# %%
# Using vector operations over loops 
start = time.time()
recent_coding_books = np.intersect1d(recent_books, coding_books)
print(len(recent_coding_books))
print('Duration: {} seconds'.format(time.time() - start))

# %%
# Using data structures
start = time.time()
recent_coding_books = set(recent_books).intersection(set(coding_books))
print(len(recent_coding_books))
print('Duration: {} seconds'.format(time.time() - start))

# %%
# Try except statements

# %%
def read_data(file_path):
    try:
        df = pd.read_csv(file_path)
        return df
    except (FileNotFoundError, SyntaxError, ImportError, TypeError):
        if FileNotFoundError:
            print('We were not able to find the path')
        else:
            print('Some other error')
    
read_data('some path')
# Out:
# We were not able to find the path

# %%
def divide_vals(numerator, denominator):
    '''
    Args:
        numerator: (float) numerator of fraction
        denominator: (float) denominator of fraction

    Returns:
        fraction_val: (float) numerator/denominator
    '''
    try:
        fraction_val = numerator/denominator
        return fraction_val
    except ZeroDivisionError:
        return 'Denominator cannot be zero'
    
print(divide_vals (4,0))
        # try to return the fraction but if the denominator is zero
    # catch the error and return a string saying: 
    # "denominator cannot be zero"

def num_words(text):
    '''
    Args:
        text: (string) string of words

    Returns:
        num_words: (int) number of words in the string
    '''
    try:
        num_words = len(text.split())
        return num_words
    except AttributeError:
        return 'text argument must be a string'
    # try to split based on spaces and return num of words
    # but if text isnt a string return "text argument must be a string"
    
print(num_words(2))
print(num_words('This is some text'))
# Out:
# Denominator cannot be zero
# text argument must be a string
# 4

# %%
# Testing

# %%
# !pip install pytest
# Out:
# Requirement already satisfied: pytest in c:\users\roland\anaconda3\lib\site-packages (7.1.2)
# Requirement already satisfied: attrs>=19.2.0 in c:\users\roland\anaconda3\lib\site-packages (from pytest) (21.4.0)
# Requirement already satisfied: iniconfig in c:\users\roland\anaconda3\lib\site-packages (from pytest) (1.1.1)
# Requirement already satisfied: packaging in c:\users\roland\anaconda3\lib\site-packages (from pytest) (21.3)
# Requirement already satisfied: pluggy<2.0,>=0.12 in c:\users\roland\anaconda3\lib\site-packages (from pytest) (1.0.0)
# Requirement already satisfied: py>=1.8.2 in c:\users\roland\anaconda3\lib\site-packages (from pytest) (1.11.0)
# Requirement already satisfied: tomli>=1.0.0 in c:\users\roland\anaconda3\lib\site-packages (from pytest) (2.0.1)
# Requirement already satisfied: atomicwrites>=1.0 in c:\users\roland\anaconda3\lib\site-packages (from pytest) (1.4.0)
# Requirement already satisfied: colorama in c:\users\roland\anaconda3\lib\site-packages (from pytest) (0.4.5)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\roland\anaconda3\lib\site-packages (from packaging->pytest) (3.0.9)

# %%
# Example
from nearest import nearest_square
def test_nearest_square_5():
    assert(nearest_square(5) == 4)
def test_nearest_square_n12():
    assert(nearest_square(-12) == 0)
def test_nearest_square_9():
    assert(nearest_square(9) == 9)
def test_nearest_square_23():
    assert(nearest_square(23) == 16)

# %%
# Parameterized tests
# File: test_mylibrary.py
# Pytest filename starts with "test_...."
import pytest

##################################
"""
Function to test
"""
def import_data(pth):
    df = pd.read_csv(pth)
    return df
##################################
"""
Fixture - The test function test_import_data() will 
use the return of path() as an argument
"""
@pytest.fixture(scope="module")
def path():
    return "./data/bank_data.csv"

##################################
"""
Test method
"""
def test_import_data(path):
    try:
        df = import_data(path)

    except FileNotFoundError as err:
        logging.error("File not found")
        raise err

    # Check the df shape
    try:
        assert df.shape[0] > 0
        assert df.shape[1] > 0

    except AssertionError as err:
        logging.error(
            "Testing import_data: The file doesn't appear to have rows and columns")
        raise err
    return df
##################################

# %%
# Logging

# %%
import logging

logging.basicConfig(
    filename='./results.log',
    level=logging.INFO,
    filemode='w',
    format='%(name)s - %(levelname)s - %(message)s')

# %%
import argparse
import logging

# %%
logging.basicConfig(level=logging.INFO,format="%(acstime)-15s %(message)s")
logger = logging.getLogger()

# %%
def go(args):
    logger.info("This is a message")
    logger.info(f"This is {args.artifact_name}")
    logger.info(f"This is {args.optional_arg}")
    logger.warning("This is a warning")
    logger.error("This is an error")
    
if __name___ == "__main__":
    parser = argparse.ArgumentParser(description="This is a tutorial for Argparser", fromfile_prefix_ch)ars="@")
    
    parser.add_argument(
        "--artifact_name", type=str, help="Name and version of W&B artifact", required=True
    )
    
    parser.add_argument(
        "--optional_arg", type=float, help="An optional argument", required=False, default=2.4
    )
    
    args = parser.parse_args()
    go(args)

# %%
import wandb

# %%
run = wandb.init(
project = "my_project",
job_type = "data_cleaning",
group = "experiment_1")

# %%
# !pip install mlflow
# Out:
# Collecting mlflow
#   Downloading mlflow-2.1.1-py3-none-any.whl (16.7 MB)
#      --------------------------------------- 16.7/16.7 MB 14.2 MB/s eta 0:00:00
# Requirement already satisfied: sqlalchemy<2,>=1.4.0 in c:\users\roland\anaconda3\lib\site-packages (from mlflow) (1.4.39)
# Collecting databricks-cli<1,>=0.8.7
#   Downloading databricks-cli-0.17.4.tar.gz (82 kB)
#      ---------------------------------------- 82.3/82.3 kB 4.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting querystring-parser<2
#   Downloading querystring_parser-1.2.4-py2.py3-none-any.whl (7.9 kB)
# Collecting shap<1,>=0.40
#   Downloading shap-0.41.0-cp39-cp39-win_amd64.whl (435 kB)
#      ------------------------------------- 435.6/435.6 kB 13.3 MB/s eta 0:00:00
# Collecting docker<7,>=4.0.0
#   Downloading docker-6.0.1-py3-none-any.whl (147 kB)
#      ---------------------------------------- 147.5/147.5 kB ? eta 0:00:00
# Requirement already satisfied: gitpython<4,>=2.1.0 in c:\users\roland\anaconda3\lib\site-packages (from mlflow) (3.1.31)
# Collecting Jinja2<4,>=3.0
#   Downloading Jinja2-3.1.2-py3-none-any.whl (133 kB)
#      ---------------------------------------- 133.1/133.1 kB ? eta 0:00:00
# Collecting waitress<3
#   Downloading waitress-2.1.2-py3-none-any.whl (57 kB)
#      ---------------------------------------- 57.7/57.7 kB ? eta 0:00:00
# Requirement already satisfied: entrypoints<1 in c:\users\roland\anaconda3\lib\site-packages (from mlflow) (0.4)
# Collecting sqlparse<1,>=0.4.0
#   Downloading sqlparse-0.4.3-py3-none-any.whl (42 kB)
#      ---------------------------------------- 42.8/42.8 kB ? eta 0:00:00
# Collecting alembic<2
#   Downloading alembic-1.9.4-py3-none-any.whl (210 kB)
#      ------------------------------------- 210.5/210.5 kB 12.5 MB/s eta 0:00:00
# Requirement already satisfied: Flask<3 in c:\users\roland\anaconda3\lib\site-packages (from mlflow) (1.1.2)
# Requirement already satisfied: scikit-learn<2 in c:\users\roland\anaconda3\lib\site-packages (from mlflow) (1.0.2)
# Requirement already satisfied: cloudpickle<3 in c:\users\roland\anaconda3\lib\site-packages (from mlflow) (2.0.0)
# Requirement already satisfied: matplotlib<4 in c:\users\roland\anaconda3\lib\site-packages (from mlflow) (3.5.2)
# Requirement already satisfied: markdown<4,>=3.3 in c:\users\roland\anaconda3\lib\site-packages (from mlflow) (3.3.4)
# Requirement already satisfied: scipy<2 in c:\users\roland\anaconda3\lib\site-packages (from mlflow) (1.9.1)
# Requirement already satisfied: pyyaml<7,>=5.1 in c:\users\roland\anaconda3\lib\site-packages (from mlflow) (6.0)
# Requirement already satisfied: requests<3,>=2.17.3 in c:\users\roland\anaconda3\lib\site-packages (from mlflow) (2.28.1)
# Requirement already satisfied: importlib-metadata!=4.7.0,<6,>=3.7.0 in c:\users\roland\anaconda3\lib\site-packages (from mlflow) (4.11.3)
# Requirement already satisfied: pandas<2 in c:\users\roland\anaconda3\lib\site-packages (from mlflow) (1.4.4)
# Requirement already satisfied: click<9,>=7.0 in c:\users\roland\anaconda3\lib\site-packages (from mlflow) (8.0.4)
# Requirement already satisfied: pytz<2023 in c:\users\roland\anaconda3\lib\site-packages (from mlflow) (2022.1)
# Requirement already satisfied: packaging<23 in c:\users\roland\anaconda3\lib\site-packages (from mlflow) (21.3)
# Collecting pyarrow<11,>=4.0.0
#   Downloading pyarrow-10.0.1-cp39-cp39-win_amd64.whl (20.3 MB)
#      --------------------------------------- 20.3/20.3 MB 15.2 MB/s eta 0:00:00
# Requirement already satisfied: protobuf<5,>=3.12.0 in c:\users\roland\anaconda3\lib\site-packages (from mlflow) (3.19.6)
# Requirement already satisfied: numpy<2 in c:\users\roland\anaconda3\lib\site-packages (from mlflow) (1.21.5)
# Collecting Mako
#   Downloading Mako-1.2.4-py3-none-any.whl (78 kB)
#      ---------------------------------------- 78.7/78.7 kB ? eta 0:00:00
# Requirement already satisfied: colorama in c:\users\roland\anaconda3\lib\site-packages (from click<9,>=7.0->mlflow) (0.4.5)
# Requirement already satisfied: pyjwt>=1.7.0 in c:\users\roland\anaconda3\lib\site-packages (from databricks-cli<1,>=0.8.7->mlflow) (2.4.0)
# Requirement already satisfied: oauthlib>=3.1.0 in c:\users\roland\anaconda3\lib\site-packages (from databricks-cli<1,>=0.8.7->mlflow) (3.2.2)
# Requirement already satisfied: tabulate>=0.7.7 in c:\users\roland\anaconda3\lib\site-packages (from databricks-cli<1,>=0.8.7->mlflow) (0.8.10)
# Requirement already satisfied: six>=1.10.0 in c:\users\roland\anaconda3\lib\site-packages (from databricks-cli<1,>=0.8.7->mlflow) (1.16.0)
# Collecting pywin32>=304
#   Downloading pywin32-305-cp39-cp39-win_amd64.whl (12.2 MB)
#      --------------------------------------- 12.2/12.2 MB 14.9 MB/s eta 0:00:00
# Requirement already satisfied: urllib3>=1.26.0 in c:\users\roland\anaconda3\lib\site-packages (from docker<7,>=4.0.0->mlflow) (1.26.11)
# Requirement already satisfied: websocket-client>=0.32.0 in c:\users\roland\anaconda3\lib\site-packages (from docker<7,>=4.0.0->mlflow) (0.58.0)
# Requirement already satisfied: Werkzeug>=0.15 in c:\users\roland\anaconda3\lib\site-packages (from Flask<3->mlflow) (2.0.3)
# Requirement already satisfied: itsdangerous>=0.24 in c:\users\roland\anaconda3\lib\site-packages (from Flask<3->mlflow) (2.0.1)
# Requirement already satisfied: gitdb<5,>=4.0.1 in c:\users\roland\anaconda3\lib\site-packages (from gitpython<4,>=2.1.0->mlflow) (4.0.10)
# Requirement already satisfied: zipp>=0.5 in c:\users\roland\anaconda3\lib\site-packages (from importlib-metadata!=4.7.0,<6,>=3.7.0->mlflow) (3.8.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\roland\anaconda3\lib\site-packages (from Jinja2<4,>=3.0->mlflow) (2.0.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\roland\anaconda3\lib\site-packages (from matplotlib<4->mlflow) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\roland\anaconda3\lib\site-packages (from matplotlib<4->mlflow) (4.25.0)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\roland\anaconda3\lib\site-packages (from matplotlib<4->mlflow) (3.0.9)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\roland\anaconda3\lib\site-packages (from matplotlib<4->mlflow) (1.4.2)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\roland\anaconda3\lib\site-packages (from matplotlib<4->mlflow) (9.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\roland\anaconda3\lib\site-packages (from matplotlib<4->mlflow) (2.8.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\roland\anaconda3\lib\site-packages (from requests<3,>=2.17.3->mlflow) (3.3)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\roland\anaconda3\lib\site-packages (from requests<3,>=2.17.3->mlflow) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\roland\anaconda3\lib\site-packages (from requests<3,>=2.17.3->mlflow) (2022.9.14)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\roland\anaconda3\lib\site-packages (from scikit-learn<2->mlflow) (2.2.0)
# Requirement already satisfied: joblib>=0.11 in c:\users\roland\anaconda3\lib\site-packages (from scikit-learn<2->mlflow) (1.2.0)
# Collecting slicer==0.0.7
#   Downloading slicer-0.0.7-py3-none-any.whl (14 kB)
# Requirement already satisfied: numba in c:\users\roland\anaconda3\lib\site-packages (from shap<1,>=0.40->mlflow) (0.55.1)
# Requirement already satisfied: tqdm>4.25.0 in c:\users\roland\anaconda3\lib\site-packages (from shap<1,>=0.40->mlflow) (4.64.1)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\roland\anaconda3\lib\site-packages (from sqlalchemy<2,>=1.4.0->mlflow) (1.1.1)
# Requirement already satisfied: smmap<6,>=3.0.1 in c:\users\roland\anaconda3\lib\site-packages (from gitdb<5,>=4.0.1->gitpython<4,>=2.1.0->mlflow) (5.0.0)
# Requirement already satisfied: setuptools in c:\users\roland\anaconda3\lib\site-packages (from numba->shap<1,>=0.40->mlflow) (63.4.1)
# Requirement already satisfied: llvmlite<0.39,>=0.38.0rc1 in c:\users\roland\anaconda3\lib\site-packages (from numba->shap<1,>=0.40->mlflow) (0.38.0)
# Building wheels for collected packages: databricks-cli
#   Building wheel for databricks-cli (setup.py): started
#   Building wheel for databricks-cli (setup.py): finished with status 'done'
#   Created wheel for databricks-cli: filename=databricks_cli-0.17.4-py3-none-any.whl size=142875 sha256=b26f83cb63c32b87830f4d8d21e6ea889d7b62af101fb2d86189275f67274db1
#   Stored in directory: c:\users\roland\appdata\local\pip\cache\wheels\b3\d4\24\ed7f421c3c600f3eee1a3a9e5c4aecc286a7622cac031918b7
# Successfully built databricks-cli
# Installing collected packages: pywin32, waitress, sqlparse, slicer, querystring-parser, pyarrow, Mako, Jinja2, docker, databricks-cli, alembic, shap, mlflow
#   Attempting uninstall: pywin32
#     Found existing installation: pywin32 302
#     Uninstalling pywin32-302:
#       Successfully uninstalled pywin32-302
#   Rolling back uninstall of pywin32
#   Moving to c:\users\roland\anaconda3\lib\site-packages\__pycache__\pythoncom.cpython-39.pyc
#    from C:\Users\Roland\AppData\Local\Temp\pip-uninstall-mcwtlq58\pythoncom.cpython-39.pyc
#   Moving to c:\users\roland\anaconda3\lib\site-packages\adodbapi
#    from C:\Users\Roland\anaconda3\Lib\site-packages\~dodbapi
#   Moving to c:\users\roland\anaconda3\lib\site-packages\isapi
#    from C:\Users\Roland\anaconda3\Lib\site-packages\~sapi
#   Moving to c:\users\roland\anaconda3\lib\site-packages\pythoncom.py
#    from C:\Users\Roland\AppData\Local\Temp\pip-uninstall-wr31p_8i\pythoncom.py
#   Moving to c:\users\roland\anaconda3\lib\site-packages\pythonwin
#    from C:\Users\Roland\anaconda3\Lib\site-packages\~ythonwin
#   Moving to c:\users\roland\anaconda3\lib\site-packages\pywin32-302-py3.9.egg-info
#    from C:\Users\Roland\anaconda3\Lib\site-packages\~ywin32-302-py3.9.egg-info
#   Moving to c:\users\roland\anaconda3\lib\site-packages\win32\lib\
#    from C:\Users\Roland\anaconda3\Lib\site-packages\win32\~ib
#   Moving to c:\users\roland\anaconda3\lib\site-packages\win32com
#    from C:\Users\Roland\anaconda3\Lib\site-packages\~in32com
#   Moving to c:\users\roland\anaconda3\lib\site-packages\win32comext
#    from C:\Users\Roland\anaconda3\Lib\site-packages\~in32comext
# ERROR: Could not install packages due to an OSError: [WinError 5] Access is denied: 'C:\\Users\\Roland\\anaconda3\\Lib\\site-packages\\win32\\_win32sysloader.pyd'
# Consider using the `--user` option or check the permissions.

# %%
# !pip install --user mlflow
# Out:
# Collecting mlflow
#   Using cached mlflow-2.1.1-py3-none-any.whl (16.7 MB)
# Requirement already satisfied: pyyaml<7,>=5.1 in c:\users\roland\anaconda3\lib\site-packages (from mlflow) (6.0)
# Requirement already satisfied: entrypoints<1 in c:\users\roland\anaconda3\lib\site-packages (from mlflow) (0.4)
# Requirement already satisfied: scipy<2 in c:\users\roland\anaconda3\lib\site-packages (from mlflow) (1.9.1)
# Collecting docker<7,>=4.0.0
#   Using cached docker-6.0.1-py3-none-any.whl (147 kB)
# Requirement already satisfied: pandas<2 in c:\users\roland\anaconda3\lib\site-packages (from mlflow) (1.4.4)
# Requirement already satisfied: Flask<3 in c:\users\roland\anaconda3\lib\site-packages (from mlflow) (1.1.2)
# Collecting Jinja2<4,>=3.0
#   Using cached Jinja2-3.1.2-py3-none-any.whl (133 kB)
# Requirement already satisfied: protobuf<5,>=3.12.0 in c:\users\roland\anaconda3\lib\site-packages (from mlflow) (3.19.6)
# Requirement already satisfied: matplotlib<4 in c:\users\roland\anaconda3\lib\site-packages (from mlflow) (3.5.2)
# Collecting sqlparse<1,>=0.4.0
#   Using cached sqlparse-0.4.3-py3-none-any.whl (42 kB)
# Requirement already satisfied: pytz<2023 in c:\users\roland\anaconda3\lib\site-packages (from mlflow) (2022.1)
# Requirement already satisfied: numpy<2 in c:\users\roland\anaconda3\lib\site-packages (from mlflow) (1.21.5)
# Requirement already satisfied: packaging<23 in c:\users\roland\anaconda3\lib\site-packages (from mlflow) (21.3)
# Collecting pyarrow<11,>=4.0.0
#   Using cached pyarrow-10.0.1-cp39-cp39-win_amd64.whl (20.3 MB)
# Requirement already satisfied: importlib-metadata!=4.7.0,<6,>=3.7.0 in c:\users\roland\anaconda3\lib\site-packages (from mlflow) (4.11.3)
# Requirement already satisfied: cloudpickle<3 in c:\users\roland\anaconda3\lib\site-packages (from mlflow) (2.0.0)
# Requirement already satisfied: requests<3,>=2.17.3 in c:\users\roland\anaconda3\lib\site-packages (from mlflow) (2.28.1)
# Collecting querystring-parser<2
#   Using cached querystring_parser-1.2.4-py2.py3-none-any.whl (7.9 kB)
# Collecting waitress<3
#   Using cached waitress-2.1.2-py3-none-any.whl (57 kB)
# Requirement already satisfied: click<9,>=7.0 in c:\users\roland\anaconda3\lib\site-packages (from mlflow) (8.0.4)
# Collecting alembic<2
#   Using cached alembic-1.9.4-py3-none-any.whl (210 kB)
# Requirement already satisfied: gitpython<4,>=2.1.0 in c:\users\roland\anaconda3\lib\site-packages (from mlflow) (3.1.31)
# Requirement already satisfied: sqlalchemy<2,>=1.4.0 in c:\users\roland\anaconda3\lib\site-packages (from mlflow) (1.4.39)
# Requirement already satisfied: markdown<4,>=3.3 in c:\users\roland\anaconda3\lib\site-packages (from mlflow) (3.3.4)
# Requirement already satisfied: scikit-learn<2 in c:\users\roland\anaconda3\lib\site-packages (from mlflow) (1.0.2)
# Collecting shap<1,>=0.40
#   Using cached shap-0.41.0-cp39-cp39-win_amd64.whl (435 kB)
# Collecting databricks-cli<1,>=0.8.7
#   Using cached databricks_cli-0.17.4-py3-none-any.whl
# Collecting Mako
#   Using cached Mako-1.2.4-py3-none-any.whl (78 kB)
# Requirement already satisfied: colorama in c:\users\roland\anaconda3\lib\site-packages (from click<9,>=7.0->mlflow) (0.4.5)
# Requirement already satisfied: six>=1.10.0 in c:\users\roland\anaconda3\lib\site-packages (from databricks-cli<1,>=0.8.7->mlflow) (1.16.0)
# Requirement already satisfied: pyjwt>=1.7.0 in c:\users\roland\anaconda3\lib\site-packages (from databricks-cli<1,>=0.8.7->mlflow) (2.4.0)
# Requirement already satisfied: tabulate>=0.7.7 in c:\users\roland\anaconda3\lib\site-packages (from databricks-cli<1,>=0.8.7->mlflow) (0.8.10)
# Requirement already satisfied: oauthlib>=3.1.0 in c:\users\roland\anaconda3\lib\site-packages (from databricks-cli<1,>=0.8.7->mlflow) (3.2.2)
# Collecting pywin32>=304
#   Using cached pywin32-305-cp39-cp39-win_amd64.whl (12.2 MB)
# Requirement already satisfied: urllib3>=1.26.0 in c:\users\roland\anaconda3\lib\site-packages (from docker<7,>=4.0.0->mlflow) (1.26.11)
# Requirement already satisfied: websocket-client>=0.32.0 in c:\users\roland\anaconda3\lib\site-packages (from docker<7,>=4.0.0->mlflow) (0.58.0)
# Requirement already satisfied: itsdangerous>=0.24 in c:\users\roland\anaconda3\lib\site-packages (from Flask<3->mlflow) (2.0.1)
# Requirement already satisfied: Werkzeug>=0.15 in c:\users\roland\anaconda3\lib\site-packages (from Flask<3->mlflow) (2.0.3)
# Requirement already satisfied: gitdb<5,>=4.0.1 in c:\users\roland\anaconda3\lib\site-packages (from gitpython<4,>=2.1.0->mlflow) (4.0.10)
# Requirement already satisfied: zipp>=0.5 in c:\users\roland\anaconda3\lib\site-packages (from importlib-metadata!=4.7.0,<6,>=3.7.0->mlflow) (3.8.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\roland\anaconda3\lib\site-packages (from Jinja2<4,>=3.0->mlflow) (2.0.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\roland\anaconda3\lib\site-packages (from matplotlib<4->mlflow) (2.8.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\roland\anaconda3\lib\site-packages (from matplotlib<4->mlflow) (1.4.2)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\roland\anaconda3\lib\site-packages (from matplotlib<4->mlflow) (9.2.0)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\roland\anaconda3\lib\site-packages (from matplotlib<4->mlflow) (3.0.9)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\roland\anaconda3\lib\site-packages (from matplotlib<4->mlflow) (4.25.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\roland\anaconda3\lib\site-packages (from matplotlib<4->mlflow) (0.11.0)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\roland\anaconda3\lib\site-packages (from requests<3,>=2.17.3->mlflow) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\roland\anaconda3\lib\site-packages (from requests<3,>=2.17.3->mlflow) (2022.9.14)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\roland\anaconda3\lib\site-packages (from requests<3,>=2.17.3->mlflow) (3.3)
# Requirement already satisfied: joblib>=0.11 in c:\users\roland\anaconda3\lib\site-packages (from scikit-learn<2->mlflow) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\roland\anaconda3\lib\site-packages (from scikit-learn<2->mlflow) (2.2.0)
# Collecting slicer==0.0.7
#   Using cached slicer-0.0.7-py3-none-any.whl (14 kB)
# Requirement already satisfied: numba in c:\users\roland\anaconda3\lib\site-packages (from shap<1,>=0.40->mlflow) (0.55.1)
# Requirement already satisfied: tqdm>4.25.0 in c:\users\roland\anaconda3\lib\site-packages (from shap<1,>=0.40->mlflow) (4.64.1)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\roland\anaconda3\lib\site-packages (from sqlalchemy<2,>=1.4.0->mlflow) (1.1.1)
# Requirement already satisfied: smmap<6,>=3.0.1 in c:\users\roland\anaconda3\lib\site-packages (from gitdb<5,>=4.0.1->gitpython<4,>=2.1.0->mlflow) (5.0.0)
# Requirement already satisfied: setuptools in c:\users\roland\anaconda3\lib\site-packages (from numba->shap<1,>=0.40->mlflow) (63.4.1)
# Requirement already satisfied: llvmlite<0.39,>=0.38.0rc1 in c:\users\roland\anaconda3\lib\site-packages (from numba->shap<1,>=0.40->mlflow) (0.38.0)
# Installing collected packages: pywin32, waitress, sqlparse, slicer, querystring-parser, pyarrow, Mako, Jinja2, docker, databricks-cli, alembic, shap, mlflow
# Successfully installed Jinja2-3.1.2 Mako-1.2.4 alembic-1.9.4 databricks-cli-0.17.4 docker-6.0.1 mlflow-2.1.1 pyarrow-10.0.1 pywin32-305 querystring-parser-1.2.4 shap-0.41.0 slicer-0.0.7 sqlparse-0.4.3 waitress-2.1.2
#   WARNING: The script waitress-serve.exe is installed in 'C:\Users\Roland\AppData\Roaming\Python\Python39\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script sqlformat.exe is installed in 'C:\Users\Roland\AppData\Roaming\Python\Python39\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script plasma_store.exe is installed in 'C:\Users\Roland\AppData\Roaming\Python\Python39\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script mako-render.exe is installed in 'C:\Users\Roland\AppData\Roaming\Python\Python39\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The scripts databricks.exe and dbfs.exe are installed in 'C:\Users\Roland\AppData\Roaming\Python\Python39\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script alembic.exe is installed in 'C:\Users\Roland\AppData\Roaming\Python\Python39\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script mlflow.exe is installed in 'C:\Users\Roland\AppData\Roaming\Python\Python39\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# anaconda-project 0.11.1 requires ruamel-yaml, which is not installed.

# %%
# ML flow within main.py
import mlflow

mlflow.run(
  # URI can be a local path or the URL to a git repository
  # here we are going to use a local path
  uri="my_project",
  # Entry point to call
  entry_point="main",
  # Parameters for that entry point
  parameters={
    "file_url": "https://...",
    "artifact_name": "my_data.csv"
  }
)

# Similar to mlflow run my_project -e main -P file_url="https://..." -P artifact_name="my_data.csv"

# %%
# Connecting two components:
import mlflow

mlflow.run(
  uri="download_data",
  entry_point="main",
  parameters={
    "file_url": "https://...",
    "output_artifact": "raw_data.csv"
  }
)

mlflow.run(
  uri="remove_duplicates",
  entry_point="main",
  parameters={
    "input_artifact": "raw_data.csv:latest",
    "output_artifact": "clean_data.csv"
  }
)

# %%
main:
  project_name: my_project
  experiment_name: dev
data:
  train_data: "exercise_6/data_train.csv:latest"
random_forest_pipeline:
  random_forest:
    n_estimators: 100
    criterion: gini
    max_depth: null

# %%
# Pipeline configuration with Hydra
import mlflow
import hydra

@hydra.main(config_name="config")
def go(config):
  # Now here config is a dictionary with our configuration
  # For example, to access the parameter train_data in the data
  # section we can just do
  train_data = config["data"]["train_data"]

  ...


if __name__=="__main__":
  go()
